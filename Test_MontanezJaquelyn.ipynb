# %%
from urllib.request import FancyURLopener
from bs4 import BeautifulSoup

# %%
class MyOpener(FancyURLopener):
    version = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; it; rv:1.8.1.11) Gecko/20071127 Firefox/2.0.0.11'
myopener = MyOpener()
# Out:
# C:\Users\DMC-L001\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: DeprecationWarning: MyOpener style of invoking requests is deprecated. Use newer urlopen functions/methods
#   app.launch_new_instance()

# %%
URL='http://www.razonsocialperu.com/'
URL ="https://www.razonsocialperu.com/empresa/"
html=myopener.open(URL).read()
soup=BeautifulSoup(html,"lxml")

#print(soup.prettify())
print('='*100)

# %%
len(industrias)
# Out:
# 292

# %%
industrias['17120 - ACABADO DE PROD. TEXTILES.']
# Out:
# 'https://www.razonsocialperu.com/ciiu/listado/acabado-de-prod-textiles-17120-0'

# %%
indubstrias
# Out:
# {'01110 - CULTIVOS DE CEREALES.': 'https://www.razonsocialperu.com/ciiu/listado/cultivos-de-cereales-01110-0',
#  '01123 - CULTIVO DE HORTALIZAS Y LEGUMBRES.': 'https://www.razonsocialperu.com/ciiu/listado/cultivo-de-hortalizas-y-legumbres-01123-0',
#  '01136 - CULTIVO DE FRUTAS.': 'https://www.razonsocialperu.com/ciiu/listado/cultivo-de-frutas-01136-0',
#  '01211 - CRIA DE GANADO.': 'https://www.razonsocialperu.com/ciiu/listado/cria-de-ganado-01211-0',
#  '01224 - CRIA DE ANIMALES DOMESTICOS.': 'https://www.razonsocialperu.com/ciiu/listado/cria-de-animales-domesticos-01224-0',
#  '01300 - EXPLOTACION MIXTA.': 'https://www.razonsocialperu.com/ciiu/listado/explotacion-mixta-01300-0',
#  '01400 - SERVICIOS AGRICOLAS, GANADERAS.': 'https://www.razonsocialperu.com/ciiu/listado/servicios-agricolas-ganaderas-01400-0',
#  '01501 - CAZA ORDINARIA Y SERVICIOS CONEXOS.': 'https://www.razonsocialperu.com/ciiu/listado/caza-ordinaria-y-servicios-conexos-01501-0',
# ...

# %% [markdown]
# <h1>Pregunta 1: </h1>

# %% [markdown]
# Encontrar los links de razón social

# %%
import re
#textito = re.findall(r'\d{5}\s[-]\s[A-Za-z0-9\s.ñÑ]*',str(soup.getText))
textito = re.findall(r'((https://www.)\w+.com/ciiu/+\w[/A-Za-z0-9-]*)',str(soup.getText))
textito
# Out:
# [('https://www.razonsocialperu.com/ciiu/listado/acabado-de-prod-textiles-17120-0',
#   'https://www.'),
#  ('https://www.razonsocialperu.com/ciiu/listado/acondicionamiento-de-edificios-45308-0',
#   'https://www.'),
#  ('https://www.razonsocialperu.com/ciiu/listado/activ-administ-publica-en-general-75113-0',
#   'https://www.'),
#  ('https://www.razonsocialperu.com/ciiu/listado/activ-auxil-ares-de-interm-financ-67190-0',
#   'https://www.'),
#  ('https://www.razonsocialperu.com/ciiu/listado/activ-de-arquitectura-e-ingenieria-74218-0',
#   'https://www.'),
#  ('https://www.razonsocialperu.com/ciiu/listado/activ-de-asesoramiento-empresarial-74145-0',
#   'https://www.'),
#  ('https://www.razonsocialperu.com/ciiu/listado/activ-de-investigacion-y-seguridad-74927-0',
#   'https://www.'),
#  ('https://www.razonsocialperu.com/ciiu/listado/activ-financ-planes-seguros-y-pens-67206-0',
#   'https://www.'),
# ...

# %%
len(textito)
# Out:
# 292

# %% [markdown]
# <h1>Pregunta 2:</h1>

# %% [markdown]
# Encotrar los correos del archivo text.txt

# %%
data = open('Test.txt','r')
texto = data.readlines()
texto
# Out:
# ['The Project Gutenberg EBook of Email 101, by John Goodwin\n',
#  '\n',
#  'This eBook is for the use of anyone anywhere at no cost and with almost no restrictions whatsoever. You may copy it, give it away or re-use it under the terms of the Project Gutenberg License included with this eBook or online at www.gutenberg.org\n',
#  '\n',
#  '** This is a COPYRIGHTED Project Gutenberg eBook, Details Below ** ** Please follow the copyright guidelines in this file. **\n',
#  '\n',
#  'Title: Email 101\n',
#  '\n',
#  'Author: John Goodwin\n',
#  '\n',
#  'Posting Date: February 9, 2012 [EBook #75] Release Date: July 17, 1993\n',
#  '\n',
#  'Language: English\n',
#  '\n',
#  '*** START OF THIS PROJECT GUTENBERG EBOOK EMAIL 101 ***\n',
#  '\n',
#  'EMAIL 101 by John Goodwin, this is an Alpha test version, your suggestions will be included in the Beta test versions, and in the final editions.\n',
#  '\n',
#  'This rough version is missing 8 out of 28 chapters and 1 out of 5 appendices.\n',
# ...

# %%
correos = re.findall(r'(\w+@+\w[/A-Za-z0-9-.]*)',str(texto))
correos
# Out:
# ['jgoodwin@adcalc.fnal.gov',
#  'joe@locoweed.chi.il.us',
#  'president@whitehouse.gov',
#  'president@whitehouse.gov',
#  'president@whitehouse.gov',
#  'pdq@hoople.usnd.edu.',
#  'listserv@hoople.usnd.edu',
#  'pdqfan@hoople.usnd.edu',
#  'request@hoople.usnd.edu',
#  'listserv@whereever.edu',
#  'pdq@hoople.usnd.edu',
#  'bach2378@bigblue.com',
#  'pdq@hoople.usnd.edu.',
#  'president@whitehouse.gov',
#  'president@whitehouse.gov',
#  'ftpmail@decwrl.dec.com',
#  'archie@archie.rutgers.edu',
#  'ftpmail@decwrl.dec.com',
#  'almanac@oes.orst.edu',
#  'ftpmail@decwrl.dec.com',
#  'request@whitehouse.gov',
#  'politics@whitehouse.gov',
#  'server@rtfm.mit.edu',
#  'server@rtfm.mit.edu',
#  'listserv@brownvm.brown.edu',
#  'listserv@auvm.american.edu',
#  'info@psi.com',
#  'info@psi.com',
#  'info@psi.com',
#  'server@rtfm.mit.edu',
#  'ftpmail@decwrl.dec.com',
#  'ftpmail@decwrl.dec.com',
#  'ftpmail@decwrl.dec.com',
#  'server@netcom.com',
#  'server@rtfm.mit.edu',
# ...

# %%
len(correos)
# Out:
# 37

# %% [markdown]
# <h1>Pregunta 3:</h1>

# %% [markdown]
# Encontrar la cantidad de repeticiones de la palabra Internet en el archivo

# %%
utexto = str(texto).upper()
pInternet = re.findall(r'(INTERNET)',str(utexto))
len(pInternet)
# Out:
# 237

# %% [markdown]
# <h1>Pregunta 4:</h1>

# %% [markdown]
# Encontrar las fechas en el formato dd/mm/aaaa, dd/mm/aa, dd-mm-aaa, dd-mm-aa

# %%
fechas = re.findall(r'\d{1,2}[/-]\d{1,2}[/-]\d{2,4}',str(texto))
fechas
# Out:
# ['0-13-0107', '2/3/1023', '6/8/2468']

# %% [markdown]
# <h1>Pregunta 5:</h1>

# %% [markdown]
# En base al archivo original generar un archivo generar un Test2.txt en e cual se realice el siguiente proceso de limpieza:
# - Palabras a minusculas
# - Palabras con más de 4 caracteres
# - Eliminar signos de puntuación

# %%
data2 = str(texto).lower()
# Out:
# '[\'the project gutenberg ebook of email 101, by john goodwin\\n\', \'\\n\', \'this ebook is for the use of anyone anywhere at no cost and with almost no restrictions whatsoever. you may copy it, give it away or re-use it under the terms of the project gutenberg license included with this ebook or online at www.gutenberg.org\\n\', \'\\n\', \'** this is a copyrighted project gutenberg ebook, details below ** ** please follow the copyright guidelines in this file. **\\n\', \'\\n\', \'title: email 101\\n\', \'\\n\', \'author: john goodwin\\n\', \'\\n\', \'posting date: february 9, 2012 [ebook #75] release date: july 17, 1993\\n\', \'\\n\', \'language: english\\n\', \'\\n\', \'*** start of this project gutenberg ebook email 101 ***\\n\', \'\\n\', \'email 101 by john goodwin, this is an alpha test version, your suggestions will be included in the beta test versions, and in the final editions.\\n\', \'\\n\', \'this rough version is missing 8 out of 28 chapters and 1 out of 5 appendices.\\n
# ...

# %%
nopunctuation = re.sub(r'[^\w\s]',' ',data2)
data3 = nopunctuation
data3
# Out:
# '  the project gutenberg ebook of email 101  by john goodwin n     n    this ebook is for the use of anyone anywhere at no cost and with almost no restrictions whatsoever  you may copy it  give it away or re use it under the terms of the project gutenberg license included with this ebook or online at www gutenberg org n     n       this is a copyrighted project gutenberg ebook  details below       please follow the copyright guidelines in this file     n     n    title  email 101 n     n    author  john goodwin n     n    posting date  february 9  2012  ebook  75  release date  july 17  1993 n     n    language  english n     n        start of this project gutenberg ebook email 101     n     n    email 101 by john goodwin  this is an alpha test version  your suggestions will be included in the beta test versions  and in the final editions  n     n    this rough version is missing 8 out of 28 chapters and 1 out of 5 appendices  n     n    copyright  c  1993 by john e  goodwin  all rig
# ...

# %%
newtest = []
for i in data3.split():
    if len(i) > 4:
        newtest.append(i)
        data4 = " ".join(newtest)
data4
# Out:
# 'project gutenberg ebook email goodwin ebook anyone anywhere almost restrictions whatsoever under terms project gutenberg license included ebook online gutenberg copyrighted project gutenberg ebook details below please follow copyright guidelines title email author goodwin posting february ebook release language english start project gutenberg ebook email email goodwin alpha version suggestions included versions final editions rough version missing chapters appendices copyright goodwin rights reserved distribute verbatim copies these course notes commercial purposes using means provided copyright notice preserved copies information taking internetworking course contact goodwin jgoodwin adcalc charles 60174 title those little machines access account internet suppose there still people given choice drive through teller person instead machine those people admit option doing things yourself schedule anywhere remember before automatic tellers banks closed weekdays saturday guess money wou
# ...

# %%
data5 = open("Test2.txt","w", encoding="UTF-8")
texto = data5.write(data4)

# %%
from gensim.models import word2vec
import numpy as np
sentences = word2vec.Text8Corpus('Test2')

# %%
model = word2vec.Word2Vec(sentences, size=200,min_count=2)

# %%
model.most_similar(positive=['internet'], topn=10)
# Out:
# C:\Users\DMC-L001\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   if __name__ == '__main__':
# [('other', 0.9773235321044922),
#  ('gutenberg', 0.9766848683357239),
#  ('computer', 0.9741094708442688),
#  ('project', 0.9734727144241333),
#  ('system', 0.9721994400024414),
#  ('information', 0.9720914363861084),
#  ('there', 0.971775233745575),
#  ('works', 0.9696806073188782),
#  ('service', 0.9691596627235413),
#  ('electronic', 0.9684709310531616)]
